# %% [markdown]
# ## Exercise 1: Simple Arithmetics
# ### Exercise 1.1

# %% [markdown]
# ### Exercise 1.2
# Use the results of the computations done in a) b) and c) to continue your analysis. To do that, you must
# store these results into objects. Keep in mind the naming rules previously seen.

# %%
## Example for a)
(result_1_1_a * result_1_1_b / (result_1_1_c + result_1_1_a^2))
# Out:
# [1] 0.9170306

# %% [markdown]
# ### Exercise 1.3
# Which ones of the following are not correct?
# - results.a
# - results_1
# - 1.results.a
# - results.computation.done.in.a
# - A.res
# - A_.res
# - A

# %%
(c(10,20,100) + 1:3)
# Out:
# [1]  11  22 103

# %% [markdown]
# ## Exercise 2: Vector Arithmetics

# %% [markdown]
# ### Question 2.1

# %% [markdown]
# ### Question 2.2

# %% [markdown]
# ### Question 2.3

# %% [markdown]
# ### Question 2.4

# %% [markdown]
# ## Exercise 3: Matrix Arithmetics

# %% [markdown]
# ### Question 3.1

# %% [markdown]
# ## Exercise 4: Data Frames

# %% [markdown]
# ### Question 4.1

# %% [markdown]
# ### Question 4.2

# %% [markdown]
# ### Question 4.3

# %% [markdown]
# ## Exercise 5: Data Frames

# %% [markdown]
# ### Question 5.1

# %% [markdown]
# ### Question 5.2

# %% [markdown]
# ### Question 5.3

# %% [markdown]
# ## Exercise 6: Vectors, matrices, data frames and functions

# %% [markdown]
# ## Exercise 7: Important Data

# %% [markdown]
# ### Question 7.1

# %% [markdown]
# ### Question 7.2

# %% [markdown]
# ### Question 7.3

# %% [markdown]
# ### Question 7.4

# %%
(StadtkreisStimmenAnteilPartei <- read.csv('https://data.stadt-zuerich.ch/dataset/politik_gemeinderatswahlen_stimmant_seit1913_od7000/download/POL700OD7000.csv'))
(bev_monat_bestand_quartier_geschl_ag_herkunft <- read.csv('https://data.stadt-zuerich.ch/dataset/bev_monat_bestand_quartier_geschl_ag_herkunft_od3250/download/BEV325OD3250.csv'))
(wahlNachAlterGeschlechtJahr <- read.csv('https://data.stadt-zuerich.ch/dataset/politik_kantonsratswahlen_btg_urnengang_alter_geschl_od7029/download/POL702OD7029.csv'))
(wahlNachJahr <- read.csv('https://data.stadt-zuerich.ch/dataset/politik_kantonsratswahlen_btg_urnengang_alter_geschl_od7029/download/POL702OD7029.csv'))
# Out:
#      Jahr Partei     ParteiNr Wahlkreis          WahlkreisSort Stimmenanteil
# 1    1913 SP         1        Stadt Zürich       0             39.1
# 2    1913 BGB/SVP    2        Stadt Zürich       0               NA
# 3    1913 FDP        3        Stadt Zürich       0             38.6
# 4    1913 GPS        4        Stadt Zürich       0               NA
# 5    1913 GLP        5        Stadt Zürich       0               NA
# 6    1913 CVP        6        Stadt Zürich       0              7.9
# 7    1913 AL         7        Stadt Zürich       0               NA
# 8    1913 EVP        8        Stadt Zürich       0               NA
# 9    1913 Demokraten 9        Stadt Zürich       0             14.4
# 10   1916 SP         1        Stadt Zürich       0             43.9
# 11   1916 BGB/SVP    2        Stadt Zürich       0               NA
# 12   1916 FDP        3        Stadt Zürich       0             33.9
# 13   1916 GPS        4        Stadt Zürich       0               NA
# ...
